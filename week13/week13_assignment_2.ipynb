# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalRavichandran27/hds5210-2023/blob/main/week13/week13_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 13 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd
data = pd.read_csv('bodyPerformance.csv')
data.shape
# Out:
# (13393, 12)

# %%
data.columns
# Out:
# Index(['age', 'gender', 'height_cm', 'weight_kg', 'body fat_%', 'diastolic',
#        'systolic', 'gripForce', 'sit and bend forward_cm', 'sit-ups counts',
#        'broad jump_cm', 'class'],
#       dtype='object')

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
unique_value_counts = list(data.nunique())
columns = list(data.columns)
unique_count_data = {}
order_wise = []
for column, count in zip(columns, unique_value_counts):
  unique_count_data[column] = count
order = sorted(unique_value_counts,reverse = True)

for count in order:
  index = unique_value_counts.index(count)
  order_wise.append(columns[index])
df = []

for column in order_wise:
  df.append([column,unique_count_data[column]])
pd.DataFrame(df,columns=['Column_name','Unique_Count'])
# Out:
#                 Column_name  Unique_Count
# 0                 weight_kg          1398
# 1                 gripForce           550
# 2   sit and bend forward_cm           528
# 3                body fat_%           527
# 4                 height_cm           467
# 5             broad jump_cm           245
# 6                  systolic           102
# 7                 diastolic            89
# 8            sit-ups counts            81
# 9                       age            44
# 10                    class             4
# 11                   gender             2

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
similar_value_columns = []
for column in data.columns:
    if data[column].nunique() == 1:
        similar_value_columns.append(column)

if len(similar_value_columns) > 0:
    print("Columns where all values are the same:")
    for column in similar_value_columns:
        print(column)
else:
    print("There are no columns with less than two unique values ")
# Out:
# There are no columns with less than two unique values

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
import matplotlib.pyplot as plt

data['height_m'] = data['height_cm'] / 100

data['BMI'] = data['weight_kg'] / (data['height_m'] ** 2)

plt.hist(data['BMI'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('Distribution of BMI')
plt.show()

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='age', y ='BMI', hue='gender')
plt.title('BMI Distribution by Gender')
plt.xlabel('BMI')
plt.show()

# %% [markdown]
# Here i have showed scatterplot which shows the distribution of body mass index (BMI) by gender, based on a dataset of body performance data. BMI is calculated by dividing weight in kilograms by height in meters squared. It is a measure of body fatness and is used to classify people as underweight, normal weight, overweight, or obese.
#
# The chart shows that the distribution of BMI is similar for men and women, with a peak in the normal weight range. However, there are some differences between the two genders. For example, there are slightly more men in the overweight and obese categories than women. Additionally, there are a few more women in the underweight category than men.
#
# Overall, this chart suggests that there is no significant difference in the distribution of BMI by gender among people with high body performance. However, it is important to note that BMI is just one measure of body fatness and does not take into account other factors such as muscle mass and body composition.

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
