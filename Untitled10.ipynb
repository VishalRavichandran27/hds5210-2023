# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalRavichandran27/hds5210-2023/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
text = requests.get("https://data.cdc.gov/api/views/g4ie-h725/rows.json?accessType=DOWNLOAD")

# %%
with open('data.json','w') as info:
  info.write(text.text)

# %%
import json
Survey = json.load(open('data.json'))

# %%
column_list = []
for each_column in Survey['meta']['view']['columns']:
  column_list.append(each_column['fieldName'].replace(':','').strip())

# %%
Survey = pd.DataFrame(Survey['data'],columns = column_list)

# %%
pd.options.display.max_columns = 100
Survey.head()
# Out:
#                   sid                                    id  position  \
# 0  row-4e8u_kb3k_ruva  00000000-0000-0000-C53E-FCF15DC98385         0
# 1  row-8djq~36zn.35a7  00000000-0000-0000-0F96-C4CBF3FA06C0         0
# 2  row-9xyn-jp2e.7r5u  00000000-0000-0000-BEA0-84C8EA112F1E         0
# 3  row-d63b_znu7_gqgu  00000000-0000-0000-F8B5-811BD962B23B         0
# 4  row-at5u_mu2v-v4dk  00000000-0000-0000-177B-9789FA975FAA         0
#
#    created_at created_meta  updated_at updated_meta meta yearstart yearend  \
# 0  1675079585         None  1675079742         None  { }      2010    2010
# 1  1675079585         None  1675079679         None  { }      2019    2019
# 2  1675079585         None  1675079679         None  { }      2019    2019
# 3  1675079585         None  1675079679         None  { }      2019    2019
# 4  1675079585         None  1675079679         None  { }      2015    2015
#
#   locationabbr    locationdesc datasource                   topic  \
# 0           OR          Oregon       NVSS  Cardiovascular Disease
# 1           AZ         Arizona      YRBSS                 Alcohol
# 2           OH            Ohio      YRBSS                 Alcohol
# 3           US   United States      YRBSS                 Alcohol
# 4           VI  Virgin Islands      YRBSS                 Alcohol
#
#                        question response datavalueunit     datavaluetype  \
# 0  Mortality from heart failure     None          None            Number
# 1       Alcohol use among youth     None             %  Crude Prevalence
# 2       Alcohol use among youth     None             %  Crude Prevalence
# 3       Alcohol use among youth     None             %  Crude Prevalence
# 4       Alcohol use among youth     None             %  Crude Prevalence
#
#   datavalue datavaluealt datavaluefootnotesymbol  datavaluefootnote  \
# 0        30           30                    None               None
# 1      29.5         29.5                    None               None
# 2      22.5         22.5                    None               None
# 3      13.9         13.9                    None               None
# 4      None         None                       -  No data available
#
#   lowconfidencelimit highconfidencelimit stratificationcategory1  \
# 0               None                None          Race/Ethnicity
# 1               24.9                34.7                  Gender
# 2               17.0                29.1                  Gender
# 3               10.4                18.4          Race/Ethnicity
# 4               None                None                  Gender
#
#                     stratification1 stratificationcategory2 stratification2  \
# 0  American Indian or Alaska Native                    None            None
# 1                            Female                    None            None
# 2                              Male                    None            None
# 3               Asian, non-Hispanic                    None            None
# 4                              Male                    None            None
#
#   stratificationcategory3 stratification3  \
# 0                    None            None
# 1                    None            None
# 2                    None            None
# 3                    None            None
# 4                    None            None
#
#                                       geolocation responseid locationid  \
# 0   POINT (-120.15503132599969 44.56744942400047)       None         41
# 1  POINT (-111.76381127699972 34.865970280000454)       None         04
# 2    POINT (-82.40426005599966 40.06021014100048)       None         39
# 3                                            None       None         59
# 4                    POINT (-64.896335 18.335765)       None         78
#
#   topicid questionid datavaluetypeid stratificationcategoryid1  \
# 0     CVD     CVD1_4            NMBR                      RACE
# 1     ALC     ALC1_1         CRDPREV                    GENDER
# 2     ALC     ALC1_1         CRDPREV                    GENDER
# 3     ALC     ALC1_1         CRDPREV                      RACE
# 4     ALC     ALC1_1         CRDPREV                    GENDER
#
#   stratificationid1 stratificationcategoryid2 stratificationid2  \
# 0              AIAN                      None              None
# 1              GENF                      None              None
# 2              GENM                      None              None
# 3               ASN                      None              None
# 4              GENM                      None              None
#
#   stratificationcategoryid3 stratificationid3
# 0                      None              None
# 1                      None              None
# 2                      None              None
# 3                      None              None
# 4                      None              None

# %%
Survey.topic.value_counts().plot(kind = 'bar',figsize =(15,8))
# Out:
# <Axes: >

# %%
Life_style = "Sleep_health_and_lifestyle_dataset.csv"
pd.read_csv(Life_style)
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#      Blood Pressure 1  Blood Pressure 2  Heart Rate  Daily Steps  \
# 0                 126                83          77         4200
# 1                 125                80          75        10000
# 2                 125                80          75        10000
# 3                 140                90          85         3000
# 4                 140                90          85         3000
# ..                ...               ...         ...          ...
# 369               140                95          68         7000
# 370               140                95          68         7000
# 371               140                95          68         7000
# 372               140                95          68         7000
# 373               140                95          68         7000
#
#     Sleep Disorder  BMI Levels
# 0             None           2
# 1             None           1
# 2             None           1
# 3      Sleep Apnea           3
# 4      Sleep Apnea           3
# ..             ...         ...
# 369    Sleep Apnea           2
# 370    Sleep Apnea           2
# 371    Sleep Apnea           2
# 372    Sleep Apnea           2
# 373    Sleep Apnea           2
#
# [374 rows x 15 columns]
